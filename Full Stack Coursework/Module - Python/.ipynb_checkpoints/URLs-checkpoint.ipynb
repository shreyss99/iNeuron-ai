# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv")
df
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
df.head()
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %%
df.columns
# Out:
# Index(['Package', 'Item', 'Title', 'Rows', 'Cols', 'n_binary', 'n_character',
#        'n_factor', 'n_logical', 'n_numeric', 'CSV', 'Doc'],
#       dtype='object')

# %%
df.shape
# Out:
# (1714, 12)

# %%
df.describe()
# Out:
#                Rows         Cols     n_binary  n_character     n_factor  \
# count  1.714000e+03  1714.000000  1714.000000  1714.000000  1714.000000
# mean   3.900833e+03    13.086348     1.931155     0.302800     1.270128
# std    3.997025e+04   171.966384    17.416499     1.266075     3.194779
# min    2.000000e+00     1.000000     0.000000     0.000000     0.000000
# 25%    3.400000e+01     3.000000     0.000000     0.000000     0.000000
# 50%    1.055000e+02     5.000000     0.000000     0.000000     0.000000
# 75%    5.847500e+02     9.000000     2.000000     0.000000     2.000000
# max    1.414593e+06  6831.000000   624.000000    17.000000    64.000000
#
#          n_logical    n_numeric
# count  1714.000000  1714.000000
# mean      0.030922    11.429988
# std       0.405278   171.905339
# min       0.000000     0.000000
# 25%       0.000000     2.000000
# 50%       0.000000     3.000000
# 75%       0.000000     7.000000
# max      11.000000  6830.000000

# %%
# title = Consumer Price Index in Argentina

df[df['Title'] == 'Consumer Price Index in Argentina']
# Out:
#   Package          Item                              Title  Rows  Cols  \
# 1     AER  ArgentinaCPI  Consumer Price Index in Argentina    80     2
#
#    n_binary  n_character  n_factor  n_logical  n_numeric  \
# 1         0            0         0          0          2
#
#                                                  CSV  \
# 1  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                  Doc
# 1  https://vincentarelbundock.github.io/Rdatasets...

# %%
# rows which contain 'data' word in the title

df.loc[df['Title'].str.contains('data')]
# Out:
#          Package            Item  \
# 187      carData            LoBD
# 208      carData        Transact
# 217      carData            Wool
# 221   causaldata            auto
# 227   causaldata     cps_mixtape
# ...          ...             ...
# 1671       tidyr          smiths
# 1678       tidyr  us_rent_income
# 1679       tidyr             who
# 1680       tidyr  world_bank_pop
# 1693         vcd        Hospital
#
#                                                   Title   Rows  Cols  \
# 187   Cancer drug data use to provide an example of ...     84     9
# 208                                    Transaction data    261     3
# 217                                           Wool data     27     4
# 221                          Automobile data from Stata     74    12
# 227       Observational counterpart to nsw_mixtape data  15992    11
# ...                                                 ...    ...   ...
# 1671                   Some data about the Smith family      2     5
# ...

# %%
# number of unique package values

df['Package'].nunique()
# Out:
# 53

# %%
# unique packages

df['Package'].unique()
# Out:
# array(['AER', 'boot', 'carData', 'causaldata', 'cluster', 'COUNT', 'DAAG',
#        'datasets', 'dplyr', 'dragracer', 'drc', 'Ecdat', 'evir',
#        'forecast', 'fpp2', 'gap', 'geepack', 'ggplot2', 'ggplot2movies',
#        'gt', 'HistData', 'HLMdiag', 'HSAUR', 'hwde', 'ISLR', 'KMsurv',
#        'lattice', 'lme4', 'lmec', 'MASS', 'mediation', 'mi', 'mosaicData',
#        'multgee', 'nycflights13', 'openintro', 'palmerpenguins', 'plm',
#        'plyr', 'pscl', 'psych', 'quantreg', 'reshape2', 'robustbase',
#        'rpart', 'sandwich', 'sem', 'Stat2Data', 'stevedata', 'survival',
#        'texmex', 'tidyr', 'vcd'], dtype=object)

# %%
# group by package

res = df.groupby('Package')
res.sum('Package')
# Out:
#                    Rows  Cols  n_binary  n_character  n_factor  n_logical  \
# Package
# AER              554496   781       189            6       268          0
# COUNT             69387   174       101            1         5          0
# DAAG             101879  1427       746           30        96          0
# Ecdat            281717  1447       277           22       216          9
# HLMdiag            8255    32         8            0        10          0
# HSAUR              4913   202        36            2        54          1
# HistData          11980   325        59            4       104          0
# ISLR              24686  7040        26            1        26          0
# KMsurv             8362   180        90            0         3          0
# MASS              20120   447        67            1       107          0
# Stat2Data        311557  1254       281            0       280          0
# ...

# %%
# unique Doc URLs

df['Doc'].unique()
# Out:
# array(['https://vincentarelbundock.github.io/Rdatasets/doc/AER/Affairs.html',
#        'https://vincentarelbundock.github.io/Rdatasets/doc/AER/ArgentinaCPI.html',
#        'https://vincentarelbundock.github.io/Rdatasets/doc/AER/BankWages.html',
#        ...,
#        'https://vincentarelbundock.github.io/Rdatasets/doc/vcd/VonBort.html',
#        'https://vincentarelbundock.github.io/Rdatasets/doc/vcd/WeldonDice.html',
#        'https://vincentarelbundock.github.io/Rdatasets/doc/vcd/WomenQueue.html'],
#       dtype=object)

# %%
# unique CSV URLs

df['CSV'].unique()
# Out:
# array(['https://vincentarelbundock.github.io/Rdatasets/csv/AER/Affairs.csv',
#        'https://vincentarelbundock.github.io/Rdatasets/csv/AER/ArgentinaCPI.csv',
#        'https://vincentarelbundock.github.io/Rdatasets/csv/AER/BankWages.csv',
#        ...,
#        'https://vincentarelbundock.github.io/Rdatasets/csv/vcd/VonBort.csv',
#        'https://vincentarelbundock.github.io/Rdatasets/csv/vcd/WeldonDice.csv',
#        'https://vincentarelbundock.github.io/Rdatasets/csv/vcd/WomenQueue.csv'],
#       dtype=object)

# %%
df['Rows'].max()
# Out:
# 1414593

# %%
# sort as per decreasing n_* columns

df.sort_values(by=['n_binary','n_character','n_factor','n_numeric','n_logical'], ascending=[False,False,False,False,False])
# Out:
#          Package           Item  \
# 383         DAAG        rockArt
# 1020  mosaicData       HELPfull
# 534        Ecdat  bankingCrises
# 224   causaldata         castle
# 201      carData          Rossi
# ...          ...            ...
# 1593   stevedata           DJIA
# 1611   stevedata           LOTI
# 1614   stevedata       min_wage
# 1660      texmex           nidd
# 1662      texmex           rain
#
#                                                   Title   Rows  Cols  \
# 383                           Pacific Rock Art features    103   641
# 1020      Health Evaluation and Linkage to Primary Care   1472   788
# 534                         Countries in Banking Crises    211    71
# 224   Data on castle-doctrine statutes and violent c...    550   138
# 201             Rossi et al.'s Criminal Recidivism Data    432    62
# ...                                                 ...    ...   ...
# 1593         Dow Jones Industrial Average, 1885-Present  36951     2
# ...

# %%
# sort for rows > 1000 and cols < 1000

df.loc[(df['Rows'] > 1000) & (df['Cols'] < 1000)]
# Out:
#      Package             Item                                          Title  \
# 10       AER  CollegeDistance                          College Distance Data
# 13       AER          CPS1988          Determinants of Wages Data (CPS 1988)
# 14       AER          CPSSW04                 Stock and Watson CPS Data Sets
# 15       AER           CPSSW3                 Stock and Watson CPS Data Sets
# 16       AER           CPSSW8                 Stock and Watson CPS Data Sets
# ...      ...              ...                                            ...
# 1664  texmex        wavesurge  Rain, wavesurge, portpirie and nidd datasets.
# 1669   tidyr       population              World Health Organization TB data
# 1679   tidyr              who              World Health Organization TB data
# 1680   tidyr   world_bank_pop            Population data from the world bank
# 1684     vcd       Bundesliga             Ergebnisse der Fussball-Bundesliga
#
# ...
