# %%
import pandas as pd

# %%
chipotle = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep="\t")
chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chipotle.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipotle.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
chipotle.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
chipotle.shape
# Out:
# (4622, 5)

# %%
chipotle['item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
chipotle.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipotle.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# Total quantity
sum(chipotle['quantity'])
# Out:
# 4972

# %%
# total item price
sum = 0
for i in range(len(chipotle['item_price'])):
    sum += float((chipotle['item_price'][i][1:]).strip())
    
sum
# Out:
# 34500.16000000046

# %%
# total item price * quantity

sum = 0
for i in range(len(chipotle['item_price'])):
    sum += float((chipotle['item_price'][i][1:]).strip()) * chipotle['quantity'][i]
    
sum
# Out:
# 39237.020000000055

# %%
# count of items ordered by group

x = chipotle.groupby('item_name')
x = x.sum()
x = x.sort_values(['quantity'])
x.head(1000)
# Out:
#                                        order_id  quantity
# item_name
# Carnitas Salad                             1500         1
# Veggie Crispy Tacos                         668         1
# Chips and Mild Fresh Tomato Salsa           279         1
# Crispy Tacos                                434         2
# Salad                                      1150         2
# Bowl                                        472         4
# Steak Salad                                2362         4
# Veggie Salad                               7265         6
# Carnitas Salad Bowl                        6693         6
# Burrito                                    1550         6
# Carnitas Crispy Tacos                      5868         8
# Veggie Soft Tacos                          5520         8
# Chicken Salad                             10465         9
# Barbacoa Salad Bowl                        9708        10
# Barbacoa Crispy Tacos                      5613        12
# ...

# %%
# max items ordered 

x = chipotle.groupby('item_name')
x = x.sum()
x = x.sort_values(['quantity'], ascending=False)
x.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
# most expensive item

chipotle.loc[(chipotle['item_price'] == chipotle['item_price'].max())]
# Out:
#       order_id  quantity            item_name  \
# 607        250         1     Steak Salad Bowl
# 1418       576         1  Barbacoa Salad Bowl
# 1421       576         1  Barbacoa Salad Bowl
# 1825       738         1  Barbacoa Salad Bowl
# 1865       756         1  Carnitas Salad Bowl
# 2600      1032         1     Steak Salad Bowl
# 2624      1042         1     Steak Salad Bowl
# 3098      1235         1     Steak Salad Bowl
# 3115      1243         1  Carnitas Salad Bowl
# 3356      1346         1  Barbacoa Salad Bowl
# 4036      1615         1     Steak Salad Bowl
# 4241      1693         1     Steak Salad Bowl
# 4390      1751         1  Barbacoa Salad Bowl
# 4391      1752         1     Steak Salad Bowl
# 4419      1762         1     Steak Salad Bowl
# 4547      1807         1     Steak Salad Bowl
# 4572      1818         1     Steak Salad Bowl
#
#                                      choice_description item_price
# ...

# %%
# order with item_name Izze

chipotle.loc[chipotle['item_name'] == 'Izze']
# Out:
#       order_id  quantity item_name choice_description item_price
# 1            1         1      Izze       [Clementine]       3.39
# 24          12         1      Izze       [Grapefruit]       3.39
# 47          21         1      Izze       [Blackberry]       3.39
# 66          30         1      Izze       [Blackberry]       3.39
# 359        155         1      Izze       [Blackberry]       3.39
# 360        155         1      Izze       [Grapefruit]       3.39
# 430        186         1      Izze       [Grapefruit]       3.39
# 579        237         1      Izze       [Clementine]       3.39
# 580        237         1      Izze       [Grapefruit]       3.39
# 1059       436         1      Izze       [Clementine]       3.39
# 1213       495         1      Izze       [Clementine]       3.39
# 1611       651         1      Izze       [Blackberry]       3.39
# 1612       651         1      Izze       [Blackberry]       3.39
# ...

# %%
# order with item_name Izze or Chips and Mild Fresh Tomato Salsa

options = ['Blackberry']

chipotle.loc[(chipotle['item_name'] == 'Izze') | (chipotle['item_name'] == 'Chips and Mild Fresh Tomato Salsa')  ]
# Out:
#       order_id  quantity                          item_name  \
# 1            1         1                               Izze
# 24          12         1                               Izze
# 47          21         1                               Izze
# 66          30         1                               Izze
# 359        155         1                               Izze
# 360        155         1                               Izze
# 430        186         1                               Izze
# 579        237         1                               Izze
# 580        237         1                               Izze
# 674        279         1  Chips and Mild Fresh Tomato Salsa
# 1059       436         1                               Izze
# 1213       495         1                               Izze
# 1611       651         1                               Izze
# 1612       651         1                               Izze
# 1680       680         1                               Izze
# ...
